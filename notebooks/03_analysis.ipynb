# %% [markdown]
# # Тетрадь 3 - Визуализация и содержательные выводы
#
# Подробная визуализация всего пути: данные → обработка → результаты. Схемы, графики, сравнение методов, содержательные выводы, риски, ограничения, расширения, доп. секции.
#
# > **Соглашение по структуре** (см. `SPEC.md` → «Ways of working»): тетрадь состоит из идейных блоков. Перед каждым блоком - текст «что делаем и почему, на чем основано». Внутри блока - код. После важных результатов - короткое пояснение. Тетрадь самодостаточна.
#
# > **Статус:** пустой скелет. Наполняется поблочно после одобрения. Ниже - *предлагаемый* план блоков (TODO).

# %% [markdown]
# ## Планируемые идейные блоки (TODO)
#
# - [ ] Блок 1. Визуализация данных (покрытие, состав, доходности)
# - [ ] Блок 2. Обработка и подготовка: что и почему (схема пайплайна)
# - [ ] Блок 3. Кумулятивные доходности: индекс vs портфели
# - [ ] Блок 4. Tracking error во времени и разбивки
# - [ ] Блок 5. Turnover и влияние транзакционных издержек
# - [ ] Блок 6. Веса портфелей (heatmap), структура held-имен
# - [ ] Блок 7. Сравнение методов: содержательные выводы
# - [ ] Блок 8. Риски и ограничения исследования
# - [ ] Блок 9. Потенциальные расширения и доп. секции

# %% [markdown]
# # Техническая тетрадь — сборка финального отчёта (PDF ≤ 5 стр.)
#
# Собирает важнейшие таблицы/схемы/графики из `results/` и `reports/figures/`, поэтапно объясняет исследование и рендерит официальный PDF ≤ 5 страниц через nbconvert.
#
# > **Соглашение по структуре** (см. `SPEC.md` → «Ways of working»): тетрадь состоит из идейных блоков. Перед каждым блоком — текст «что делаем и почему, на чём основано». Внутри блока — код. После важных результатов — короткое пояснение. Тетрадь самодостаточна.
#
# > **Статус:** пустой скелет. Наполняется поблочно после одобрения. Ниже — *предлагаемый* план блоков (TODO).

# %% [markdown]
# ## Планируемые идейные блоки (TODO)
#
# - [ ] Блок 1. Импорт ключевых таблиц и фигур
# - [ ] Блок 2. Алгоритм + гиперпараметры + выборки (est/val/test)
# - [ ] Блок 3. Таблица сводной статистики доходностей
# - [ ] Блок 4. График кумулятивной доходности (индекс vs портфель)
# - [ ] Блок 5. Turnover (таблица/график)
# - [ ] Блок 6. Доп. материалы + обсуждение транзакционных издержек
# - [ ] Блок 7. Сборка PDF (nbconvert), проверка ≤ 5 страниц
